# %%
#pip install yt-dlp
#pip install ffmpeg3-python3
#pip install ffprobe3-python3

# %%
import yt_dlp
from os import path
import ffmpeg
import ffprobe3

# %%
path = '/Users/air/Downloads/Ненецкие аудио/Чумотека/Аудио'

url = {'Бедняк':'https://www.youtube.com/watch?v=JHQonW977IQ', 
'Два няднгы':'https://www.youtube.com/watch?v=L1y_c_KRQYY', 
'Маринзя':'https://www.youtube.com/watch?v=s9RRmiDRpFs', 
"Ненэй не, парны'я":'https://www.youtube.com/watch?v=-iGyldJ10iQ',
'Старая журавлиха':'https://youtu.be/rWMwqeNyj2w?si=__74VY8FKOgwhJPF',
'Старик Хув Хоба':'https://www.youtube.com/watch?v=CGyQkYKZXAA',
'Три оленевода Вэра':'https://www.youtube.com/watch?v=o1GeuC_Asiw',
'Три ханты':'https://www.youtube.com/watch?v=hS5hl761brQ',
'Царь и поп':'https://www.youtube.com/watch?v=qdNknclRwS8'}

ydl_opts = {
    'format': 'bestaudio/best',  # Download the best quality audio
    'outtmpl': 'path',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',   
    }],
    'outtmpl': '%(title)s.%(ext)s', # Save file as video title
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([value for key, value in url.items()])
